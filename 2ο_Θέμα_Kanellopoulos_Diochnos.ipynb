# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: ΣΠΥΡΙΔΩΝ ΑΛΕΞΑΝΔΡΟΣ ΔΙΩΧΝΟΣ - 031 15 727
#
# Στοιχεία Μέλους 2: ΓΕΩΡΓΙΟΣ ΕΦΡΑΙΜ ΚΑΝΕΛΛΟΠΟΥΛΟΣ - 031 16 115

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

import os
# με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
path = "drive/MyDrive/AI_Prog_2"
os.listdir(path)
# Out:
# Mounted at /content/drive
# ['db.pl', 'train_ratings.csv', 'test_ratings.csv', 'movies_metadata.csv']

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %% [markdown]
# ## Ερώτημα 1α: Κατασκευή Κατηγορημάτων
#
# Αρχικά κατασκευάζουμε τα παρακάτω κατηγορημάτα της βάσης γνώσης με τη χρήση της Prolog:
#
# ```
# id(Movie, Id).
# budget(Movie, Budget).
# genre(Movie, Genre).
# plot_keys(Movie, Plot_keywords).
# language(Movie, Language).
# popularity(Movie, Popularity).
# decade(Movie, Decade).
# country(Movie, Country).
# director(Movie, Director).
# actor1(Movie, Actor).
# actor2(Movie, Actor).
# actor3(Movie, Actor).
# studio_name(Movie, Studio).
# studio_id(Movie, Studio_id).
#
# ```

# %%
import pandas as pd
from pyswip import Prolog
import random

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "/movies_metadata.csv") 

#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget  ...      actor_2_name       actor_3_name
# 0           0  237000000  ...  Sigourney Weaver       Stephen Lang
# 1           1  300000000  ...   Keira Knightley  Stellan Skarsgård
# 2           2  245000000  ...       Léa Seydoux      Ralph Fiennes
# 3           3  250000000  ...       Gary Oldman      Anne Hathaway
# 4           4  260000000  ...   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()
import math

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):

###############----getting the values from the csv----------########################################
  movie_title = clean_text(getattr(row, 'movie_title'))
  id = getattr(row, 'id') 
  budget = getattr(row, 'budget')
  language = clean_text(getattr(row, 'language'))
  popularity = getattr(row, 'popularity')
  year = getattr(row, 'title_year')
  country = clean_text(getattr(row, 'country'))
  director = clean_text(getattr(row, 'director_name'))
  actor1 = clean_text(getattr(row, 'actor_1_name'))
  actor2 = clean_text(getattr(row, 'actor_2_name'))
  actor3 = clean_text(getattr(row, 'actor_3_name'))
  movie_plot = clean_text(getattr(row, 'plot_keywords'))
  production_companies = clean_text(getattr(row, 'production_companies'))

###############################----------no modifications literals----------------#################################
  if (id!='UNK'):
    literals.append("id('"+ movie_title +"','"+ str(id) +"')")

  if (budget!='UNK'):
    literals.append("budget('"+ movie_title +"','"+ str(budget) +"')")
  
  if (language!='UNK'):
    literals.append("language('"+ movie_title +"','"+ language +"')")
    
  if (popularity!='UNK'):
    literals.append("popularity('" + movie_title + "','" + str(popularity) + "')")

  if (year!='UNK'):
    literals.append("year('"+ movie_title +"','"+ str(int(year)) +"')")
    
  if (country!='UNK'):
    literals.append("country('"+ movie_title +"','"+ country +"')")

  if (director!='UNK'):
    literals.append("director('"+ movie_title +"','"+ director +"')")
    
  if (actor1!='UNK'):
    literals.append("actor1('"+ movie_title +"','"+ actor1 +"')")
    
  if (actor2!='UNK'):
    literals.append("actor2('"+ movie_title +"','"+ actor2 +"')")
    
  if (actor3!='UNK'):
    literals.append("actor3('"+ movie_title +"','"+ actor3 +"')")
  
#########################-------------split if nesessssery######################################
  for genre in getattr(row, 'genres').split("|"):                  
    literals.append("genre('"+ movie_title +"','"+ genre +"')")
  
  if (movie_plot!='UNK'):
    for plot_keyword in movie_plot.split("|"):
      literals.append("plot_keys('"+ movie_title +"','"+ plot_keyword +"')")

#########################-------------derive decade from year #################################
  if (year!='UNK'):
    decade=(math.floor(int(year)/10))
    literals.append("decade('"+ movie_title +"','"+ str(decade) +"')")
################  derive production company name and id ###############################
  if (production_companies!='UNK'):
    for studio in production_companies.split('{'):
      if studio!='[' and len(production_companies)>2:
        studio_name=studio.split(',')[0][6:]
        studio_id=''.join(c for c in studio.split(',')[1] if c.isdigit())
        
        literals.append("studio_name('"+ movie_title +"','"+ studio_name +"')")
        literals.append("studio_id('"+ movie_title +"','"+ str(studio_id) +"')")        


#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)

#for literal in literals:
 # print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "/db.pl")

# %% [markdown]
# ## Ερώτημα 1β: Κατασκευή Κανόνων Βάσης
#
# Έπειτα κατασκευάζουμε τους παρακάτω κανόνες της Βάσης Prolog:
#
# ```
# similar_theme_high(X, Y) :- 4 λέξεις σχετικά με το genre κοινές
# similar_theme_med(X, Y) :- 3 λέξεις σχετικά με το genre κοινές
# similar_theme_low(X, Y) :- 1 λέξη σχετικά με το genre κοινές
# common_director(X, Y) :- Κοινός σκηνοθέτης
# similar_plot_high(X, Y) :- 3 κοινές λέξεις πλοκής
# similar_plot_med(X, Y) :- 2 κοινές λέξεις πλοκής
# similar_plot_low(X, Y) :- 1 κοινή λέξη πλοκής
# similar_actors_high(X, Y) :- 3 κοινοί ηθοποιοί
# similar_actors_med(X, Y) :- 2 κοινοί ηθοποιοί
# similar_actors_low(X, Y) :- 1 κοινός ηθοποιός
# same_lang(X, Y) :- ίδια γλώσσα
# blacknwhite(X, Y) :- αν είναι ασπρόμαυρη
# same_country(X, Y) :- κοινή χώρα παραγωγής
# same_decade(X, Y) :- κοινή δεκαετία
# ```

# %%
# 4 similar themes
prolog.assertz('''(similar_theme_high(X, Y):-
                                        genre(X, G1), genre(Y, G1), X \= Y,
                                        genre(X, G2), genre(Y, G2), G1 \=G2,
                                        genre(X, G3), genre(Y, G3), G1 \=G3, G2 \=G3,
                                        genre(X, G4), genre(Y, G4), G1 \=G4, G2 \=G4, G3 \=G4
                                         )''')
#3 similar themes
prolog.assertz('''(similar_theme_med(X, Y):-
                                        genre(X, G1), genre(Y, G1), X \= Y,
                                        genre(X, G2), genre(Y, G2), G1 \=G2,
                                        genre(X, G3), genre(Y, G3), G1 \=G3, G2 \=G3
                                         )''')

# 1 similar theme 
prolog.assertz('''(similar_theme_low(X, Y):-
                                        genre(X, G1), genre(Y, G1), X \= Y
                                         )''')
# same director
prolog.assertz('''(common_director(X,Y):-  
                                        director(X, G1),
                                        director(Y, G1),
                                        X\=Y)''')
# 3 similar plot points
prolog.assertz('''(similar_plot_high(X, Y):-
                                        plot_keys(X, G1), plot_keys(Y, G1),X \= Y,
                                        plot_keys(X, G2), plot_keys(Y, G2),G1 \=G2,
                                        plot_keys(X, G3), plot_keys(Y, G3),G1 \=G3,G2 \=G3
                                         )''')
# 2 similar plot points
prolog.assertz('''(similar_plot_med(X, Y):-
                                        plot_keys(X, G1), plot_keys(Y, G1),X \= Y,
                                        plot_keys(X, G2), plot_keys(Y, G2),G1 \=G2
                                         )''')
# 1 similar plot point
prolog.assertz('''(similar_plot_low(X, Y):-
                                        plot_keys(X, G1), plot_keys(Y, G1),X \= Y
                                         )''')

# 3 common actors
prolog.assertz('''(similar_actors_high(X, Y):-
                                        (actor1(X, G1), actor1(Y, G1), actor2(X, G2),  actor2(Y, G2), actor3(X, G3),  actor3(Y, G3);
                                        actor1(X, G1),  actor1(Y, G1), actor2(X, G2),  actor3(Y, G2), actor3(X, G3),  actor2(Y, G3);
                                        actor1(X, G1),  actor2(Y, G1), actor2(X, G2),  actor1(Y, G2), actor3(X, G3),  actor2(Y, G3);
                                        actor1(X, G1),  actor2(Y, G1), actor2(X, G2),  actor3(Y, G2), actor3(X, G3),  actor1(Y, G3);
                                        actor1(X, G1),  actor3(Y, G1), actor2(X, G2),  actor2(Y, G2), actor3(X, G3),  actor1(Y, G3);
                                        actor1(X, G1),  actor3(Y, G1), actor2(X, G2),  actor1(Y, G2), actor3(X, G3),  actor2(Y, G3)),
                                        G1 \=G3, G2 \=G3, X \=Y
                                            )''')
# 2 common actors
prolog.assertz('''(similar_actors_med(X, Y):-
                                        (actor1(X, G1), actor1(Y, G1) ,
                                        actor2(X, G2),  actor2(Y, G2) ; 
                                        actor2(X, G1),  actor2(Y, G1) , 
                                        actor3(X, G2),  actor3(Y, G2) ;
                                        actor1(X, G1),  actor1(Y, G1) ,
                                        actor3(X, G2),  actor3(Y, G2) ;
                                        actor1(X, G1),  actor2(Y, G1) ,
                                        actor3(X, G2),  actor3(Y, G2) ;
                                        actor2(X, G1),  actor1(Y, G1) ,
                                        actor3(X, G2),  actor3(Y, G2) ;
                                        actor1(X, G1),  actor1(Y, G1) ,
                                        actor2(X, G2),  actor3(Y, G2) ;
                                        actor1(X, G1),  actor1(Y, G1) ,
                                        actor3(X, G2),  actor2(Y, G2) ;
                                        actor2(X, G1),  actor2(Y, G1) ,
                                        actor1(X, G2),  actor3(Y, G2) ;
                                        actor2(X, G1),  actor2(Y, G1) ,
                                        actor3(X, G2),  actor1(Y, G2)),                                         
                                        G1 \=G2, X \=Y
                                           )''')

# 1 common actor
prolog.assertz('''(similar_actors_low(X, Y):-
                                        (actor1(X, G1), actor1(Y, G1) ;
                                        actor2(X, G1),  actor2(Y, G1) ;
                                        actor3(X, G1),  actor3(Y, G1) ;
                                        actor1(X, G1),  actor2(Y, G1) ;
                                        actor2(X, G1),  actor3(Y, G1) ;
                                        actor3(X, G1),  actor1(Y, G1) ;
                                        actor2(X, G1),  actor1(Y, G1) ;
                                        actor3(X, G1),  actor2(Y, G1) ;
                                        actor1(X, G1),  actor3(Y, G1)),
                                        X \=Y
                                          )''')

# same language
prolog.assertz('''(same_lang(X, Y):-
                                        language(X, G1), language(Y, G1), X \= Y                                      
                                         )''')

# black and white
prolog.assertz('''(blacknwhite(X,Y):- (plot_keys(X,'black and white to color'),
                                     plot_keys(Y,'black and white to color'),X \= Y);
                                    (plot_keys(X, 'black and white'),                                      
                                     plot_keys(Y, 'black and white'), X\=Y)
                                         )''')

# same country
prolog.assertz('''(same_country(X, Y):-
                                        country(X, G1), country(Y, G1), X \= Y                                      
                                         )''')

# same year
prolog.assertz('''(same_year(X, Y):-
                                        year(X, G1), year(Y, G1), X \= Y                                      
                                         )''')

# same decade
prolog.assertz('''(same_decade(X, Y):-
                                        decade(X, G1), decade(Y, G1), X \= Y                                      
                                         )''')

# same production studio
prolog.assertz('''(same_studio(X, Y):-
                                        studio_id(X, G1), studio_id(Y, G1), X \= Y                                      
                                         )''')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευάσουμε queries τα οποία επιστρέφουν παρόμοιες ταινίες.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
######## --------------------------------- 5 levels of similarity that usualy give us good results but we have changed them a few times


prolog.assertz('''(find_similar_5(X, Y):-   (similar_theme_high(X, Y);
                                            similar_actors_high(X,Y);
                                            common_director(X,Y)),
                                            (similar_plot_high(X, Y);
                                            similar_actors_high(X,Y));
                                            blacknwhite(X,Y),               
                                            same_lang(X, Y)
                                            )''')

prolog.assertz('''(find_similar_4(X, Y):-   (similar_theme_med(X, Y);
                                            common_director(X,Y)),
                                            (similar_plot_med(X, Y);
                                            similar_actors_med(X,Y)),
                                            same_lang(X, Y),
                                            X \= Y
                                            )''')

prolog.assertz('''(find_similar_3(X, Y):-   similar_theme_med(X, Y),
                                            (similar_actors_med(X, Y);
                                            similar_plot_low(X, Y)),
                                            same_lang(X, Y),
                                            X \= Y
                                            )''')

prolog.assertz('''(find_similar_2(X, Y):-   similar_theme_low(X, Y),
                                            (similar_plot_low(X, Y);
                                            similar_actors_low(X, Y);
                                            similar_theme_med(X,Y)),
                                            X \= Y
                                            )''')

prolog.assertz('''(find_sim_1(X, Y):-   similar_theme_low(X, Y),
                                            (similar_plot_low(X, Y);
                                            same_lang(X, Y)),
                                            X \= Y
                                            )''')

prolog.assertz('''(find_similar_1(X, Y):-   similar_theme_low(X, Y),
                                            X \= Y
                                            )''')

# %%
def simple_recommender(movie):
  
    answers = []

    s5 = set()
    q5 = prolog.query("find_similar_5('" + movie +"',M) ")
    for soln in q5:
      m = soln['M'] 
      if m not in s5:
         s5.add(m)
    q5.close()

    s4 = set()
    q4 = prolog.query("find_similar_4('" + movie +"',M) ")
    for soln in q4:
      m = soln['M'] 
      if m not in s4:
         s4.add(m)
    q4.close()

    s3 = set()
    q3 = prolog.query("find_similar_3('" + movie +"',M) ")
    for soln in q3:
        m = soln['M'] 
        if m not in s3:
            s3.add(m)
    q3.close()

    s2 =set()
    q2 = prolog.query("find_similar_2('" + movie +"',M)")
    for soln in q2:
        m = soln['M'] 
        if m not in s2:
            s2.add(m)
    q2.close()

    s1 =set()
    q1 = prolog.query("find_similar_1('" + movie +"',M)")
    for soln in q1:
        m = soln['M'] 
        if m not in s1:
            s1.add(m)
    q1.close()


#############   we use tuple so we can hash it
    answers.insert(0,tuple(s5))
    answers.insert(1,tuple(s4 - s5))
    answers.insert(2,tuple(s3 - s4 - s5))
    answers.insert(3,tuple(s2 - s3 - s4 - s5))
    answers.insert(4,tuple(s1 - s2 - s3 - s4 - s5))

    return answers

# %% [markdown]
# Παρακάτω βλέπουμε ένα παράδειγμα για την simple_recommender και την ταινία Iron Man 2, όπου εμφανίζονται οι προτεινόμενες ταινίες με φθίνουσα σειρά.

# %%
similar_movies = simple_recommender('Iron Man 2')
for i in range(5):
     print(similar_movies[i])
     print(len(similar_movies[i]))

print(similar_movies[0])
# Out:
# ('Iron Man',)
# 1
# ('Ant-Man', 'Man of Steel', 'Superman III', 'Teenage Mutant Ninja Turtles', 'Superman', 'Fantastic Four', 'Avengers: Age of Ultron', 'Mystery Men', 'X-Men: The Last Stand', 'Guardians of the Galaxy', 'X-Men: Days of Future Past', 'Superman II', 'Dragonball Evolution', 'The Wolverine', 'X2', 'Captain America: The Winter Soldier', 'The Shadow', 'The Avengers', 'Iron Man 3', 'Superman Returns', 'X-Men', 'X-Men Origins: Wolverine')
# 22
# ('Street Fighter: The Legend of Chun-Li', 'The Blood of Heroes', 'Superman IV: The Quest for Peace', 'Green Lantern', 'Batman', 'Spawn', 'Suicide Squad', 'Battleship', 'G.I. Joe: The Rise of Cobra')
# 9
# ('ParaNorman', 'Journey 2: The Mysterious Island', 'The Sorcerers Apprentice', 'Blade', 'On Her Majestys Secret Service', 'Dead Man Down', 'The Phantom', 'Four Brothers', 'Star Wars: Episode III - Revenge of the Sith', 'Megaforce', 'Furious 7', 'Men in Black', 'Predators', 'Wanted', 'Red State', 'Repo Men', 'Chain Reaction', 'Kill Bill: Vol. 2', 'Nothing to Lose', 'Pirates of the Caribbean: On Stranger Tides', '2012', 'The Day After Tomorrow', 'R.I.P.D.', 'Letters to God', 'Thor: The Dark World', 'Jupiter Ascending', 'Final Fantasy: The Spirits Within', 'Star Trek Into Darkness', 'The Amazing Spider-Man 2', 'U.F.O.', 'Prometheus', 'Rambo: First Blood Part II', 'Ninja Assassin', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Predator', 'Unbreakable', 'Wild Wild West', 'Hancock', 'I Am Number Four', 'The Brothers Grimm', 'The Other Guys', 'X-Men: First Class', '15 Minutes', 'RoboCop 3', 'Six-String Samurai', 'Crank', 'Batman Begins', 'Pacific Rim', 'Defendor', 'Planet of the Apes', 'The Host', 'Batman Returns', 'The Empire Strikes Back', 'Volcano', 'Kick-Ass', 'The Quick and the Dead', 'The Man with the Golden Gun', 'The Amazing Spider-Man', 'Thunderbirds', 'Stealth', 'AVP: Alien vs. Predator', 'The Black Hole', 'All Superheroes Must Die', 'Star Trek: Generations', 'Teenage Mutant Ninja Turtles III', 'A Sound of Thunder', '3 Ninjas Kick Back', 'Aladdin', 'Face/Off', 'Star Wars: Episode I - The Phantom Menace', 'The Green Hornet', 'Titan A.E.', 'MacGruber', 'Spy Kids 3-D: Game Over', 'Timeline', 'The Lovers', 'The Lost World: Jurassic Park', 'Inception', 'Double Impact', 'Logans Run', 'Batman & Robin', 'Ghost Rider', 'Terminator Genisys', 'Oldboy', 'Hot Rod', 'Starship Troopers', 'Resident Evil: Afterlife', 'Astro Boy', 'Batman v Superman: Dawn of Justice', 'Star Trek', 'Chain of Command', 'The Boondock Saints II: All Saints Day', 'The Spirit', '9', 'Run All Night', 'The Punisher', 'Harold & Kumar Escape from Guantanamo Bay', 'X-Men: Apocalypse', 'Slither', 'Spider-Man', 'Red Sonja', 'V for Vendetta', 'The Island', 'Moby Dick', 'The Dark Knight Rises', 'Big Hero 6', 'Eight Legged Freaks', 'Star Trek: Insurrection', 'Kick-Ass 2', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'Jimmy Neutron: Boy Genius', 'The Equalizer', 'The Abyss', 'Godzilla 2000', 'Race to Witch Mountain', 'Star Trek V: The Final Frontier', 'The Covenant', 'Independence Day: Resurgence', 'Contagion', 'Fantastic Mr. Fox', 'Armageddon', 'Avatar', 'Escape from L.A.', 'Death Sentence', 'Diamonds Are Forever', 'The Matrix Reloaded', 'VeggieTales: The Pirates Who Dont Do Anything', 'Sky Captain and the World of Tomorrow', 'Mad Max', 'Shin Godzilla', 'Munich', 'Star Trek II: The Wrath of Khan', 'Enders Game', 'Anacondas: The Hunt for the Blood Orchid', 'Chronicle', 'The Incredibles', 'Austin Powers: The Spy Who Shagged Me', 'Pirates of the Caribbean: Dead Mans Chest', 'In the Name of the King: A Dungeon Siege Tale', 'Serenity', 'Pirates of the Caribbean: At Worlds End', 'Paycheck', 'Road House', 'Bee Movie', 'Fantastic 4: Rise of the Silver Surfer', 'Live and Let Die', 'The Core', '30 Minutes or Less', 'Mad Max 2: The Road Warrior', 'Austin Powers: International Man of Mystery', 'Small Soldiers', 'The Mask of Zorro', 'The Replacement Killers', 'The Country Bears', 'Divergent', 'Righteous Kill', 'TRON: Legacy', 'Return of the Jedi', 'The Matrix Revolutions', 'Knowing', 'The Hunger Games: Mockingjay - Part 2', 'Independence Day', 'Never Back Down', 'Captain America: Civil War', 'Journey to the Center of the Earth', 'Mortdecai', 'The Revenant', 'I Am Wrath', 'Blade II', 'The Dark Knight', 'Star Wars: Clone Wars: Volume 1', 'Harry Potter and the Chamber of Secrets', 'Sheena', 'Damnation Alley', 'Johnny English Reborn', 'Babylon A.D.', 'Hellboy II: The Golden Army', 'The Pirates! In an Adventure with Scientists!', 'Special', 'Riddick', 'Mission: Impossible III', 'Steel', 'Transformers', 'Deep Rising', 'Harry Potter and the Prisoner of Azkaban', 'The ...
# 295
# ('Punisher: War Zone', 'Midnight Run', 'The Hobbit: The Battle of the Five Armies', 'Bloodsport', 'The Walk', 'The Legend of Hercules', 'First Blood', 'Lifeforce', 'Seventh Son', 'Meteor', 'Mission: Impossible - Rogue Nation', 'Phenomenon', 'H.', 'Operation Chromite', 'Nighthawks', 'Priest', 'Digimon: The Movie', 'The Masked Saint', 'Flight of the Intruder', 'Menace II Society', 'Duma', 'First Knight', 'Carriers', 'St. Trinians', 'In Too Deep', 'A Low Down Dirty Shame', 'The Brothers Bloom', 'Die Hard', 'Raise the Titanic', 'Ace Ventura: When Nature Calls', 'The Day the Earth Stood Still', 'Dawn of the Dead', 'The Last Godfather', 'Heavy Metal', 'Ex Machina', 'Double Take', 'Ice Age', 'The Art of War', 'I Am Legend', 'Battlefield Earth', 'Need for Speed', 'The Man from Earth', 'Grabbers', 'Creative Control', 'Dracula Untold', 'Kickboxer: Vengeance', 'RockNRolla', 'The Life Aquatic with Steve Zissou', 'Bad Boys II', 'Platoon', 'Alice in Wonderland', 'Victor Frankenstein', 'Abraham Lincoln: Vampire Hunter', 'The Young and Prodigious T.S. Spivet', '13 Hours: The Secret Soldiers of Benghazi', 'Rumble in the Bronx', 'Clash of the Titans', 'Dragon Nest: Warriors Dawn', 'Eternal Sunshine of the Spotless Mind', 'Timecrimes', 'Black Hawk Down', 'The Musketeer', 'Corky Romano', 'The Great Escape', 'Time Changer', 'The Count of Monte Cristo', 'Lions for Lambs', 'Alien Zone', 'Red Sky', 'The Pacifier', 'Baby Geniuses', 'The Scorpion King', 'Bloody Sunday', 'Snakes on a Plane', 'Crocodile Dundee in Los Angeles', 'Nerve', 'Rio', 'Fury', 'Elysium', 'E.T. the Extra-Terrestrial', 'Edge of Tomorrow', 'The Blues Brothers', 'Battle for the Planet of the Apes', 'A Simple Wish', 'Act of Valor', 'Crimson Tide', 'Land of the Lost', 'The Last of the Mohicans', 'Batman: The Dark Knight Returns, Part 2', 'Pan', 'Bronson', 'Diary of the Dead', 'Rush Hour 3', 'Street Fighter', 'xXx', 'Silmido', 'The Timber', 'Blue Streak', 'The Monuments Men', 'S.W.A.T.', 'Deep Impact', 'Gun Shy', 'Tracker', 'The X Files: I Want to Believe', 'Windtalkers', '1911', 'Return of the Living Dead 3', 'The Misfits', 'Casino Royale', 'Feast', 'Ink', 'Royal Kill', 'Tora! Tora! Tora!', 'The Transporter Refueled', 'Dragon Wars: D-War', 'Looper', 'Species', 'Class of 1984', 'Blackthorn', 'The Assassination of Jesse James by the Coward Robert Ford', 'The Warlords', 'Percy Jackson & the Olympians: The Lightning Thief', 'The Walking Deceased', 'Galaxy Quest', 'Benji', 'Troy', 'Witless Protection', 'Laws of Attraction', 'WarGames', 'The Forbidden Kingdom', 'Seeking a Friend for the End of the World', 'Mortal Kombat', 'The Lion of Judah', 'Born Of War', '300', 'The Bourne Legacy', 'Wind Walkers', 'Das Boot', 'Firestarter', 'The Man', 'The Three Burials of Melquiades Estrada', 'George of the Jungle', 'Boom Town', 'Life of Pi', 'Captain Phillips', 'The Iron Giant', 'Lockout', 'The Ballad of Cable Hogue', 'The Wiz', 'Brooklyn Rules', 'Kingdom of Heaven', 'Gangster Squad', 'Last Action Hero', 'Prince of Persia: The Sands of Time', 'GoldenEye', 'Apollo 18', 'Day of the Dead', 'Northfork', 'Real Steel', 'Wing Commander', 'Rush Hour 2', 'Warlock', 'Self/less', 'Excessive Force', 'They Live', 'Without a Paddle', 'Jane Got a Gun', 'Smillas Sense of Snow', 'Allegiant', 'Its a Mad, Mad, Mad, Mad World', 'Gone in Sixty Seconds', 'The Matrix', 'The Beast from 20,000 Fathoms', 'The Longest Day', 'Home Alone 2: Lost in New York', 'Men in Black 3', 'Crossroads', 'Live Free or Die Hard', 'Unsullied', 'City of Ember', 'The Divide', 'Oz: The Great and Powerful', 'Airborne', 'Die Hard 2', 'The NeverEnding Story', 'Outbreak', 'Forbidden Kingdom', 'Escape from New York', 'Herbie Fully Loaded', 'Rockaway', 'Catch a Fire', 'Pitch Black', 'Point Break', 'Homefront', 'Nancy Drew', 'This Means War', 'Thunder and the House of Magic', 'The Huntsman: Winters War', 'Ride Along', 'The Living Daylights', 'Taken', 'The Proposition', 'Payback', 'The Secret Life of Bees', 'The Mighty Macs', 'Shanghai Noon', 'Penguins of Mad ...
# 1350
# ('Iron Man',)

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -2, 1: -1, 2: -0.5, 3: 0.5, 4: 1, 5: 2}
score_weights = {0: 3, 1: 2, 2: 1, 3: 1, 4: 1} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]


  
    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating') 

        similar_movies = simple_recommender(movie)

        ########### our similar movies are 2d so we have to add a second for loop     ################################
        for j in range(5):
            for similar_movie in similar_movies[j]:
              if similar_movie not in movie_score:
                  movie_score[similar_movie] =  score_weights[j]*rating_weights[int(rating)] 
              else:
                  movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[j] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος

        
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

train_ratings = pd.read_csv(path + "/train_ratings.csv")
test_ratings = pd.read_csv(path + "/test_ratings.csv")

# %% [markdown]
# Οι παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Συνεπώς, από κάτω τρέχουμε 10 πειράματα για υποσύνολο 3 ταινιών, έπειται για 10, 30 και, τέλος, για ολόκληρο το σύνολο.

# %%
metrics = []
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
real, pred = predict_example(test_ratings, movie_score)
print(get_metrics(real, pred))
# Out:
# 0it [00:00, ?it/s]
# {'precision': 0.5071428571428571, 'recall': 0.9861111111111112, 'f1': 0.6698113207547169}

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 3)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))
for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.4999004194078259
# recall: 0.7874999999999999
# f1: 0.6009586295718176

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5086003330966432
# recall: 0.8930555555555555
# f1: 0.6409612328434389

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5047346817956011
# recall: 0.9541666666666666
# f1: 0.6601107213566547

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, -1)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5106382978723404
# recall: 1.0
# f1: 0.676056338028169

# %% [markdown]
# Παρατηρούμε πως το μοντέλο μας προβλέπει σωστά ποιες ταινίες να προβλέψει και εμφανίζει ένα ψηλό recall αρκετά κοντά στο 1, αλλά προτείνει και ταινίες που δεν θα έπρεπε, οπότε έχουμε ένα μέτριο precision (~0.5). Αυτό λογικά συμβαίνει γιατί κάνουμε υπερεκτίμηση σε κάποιες ταινίες χωρίς να χρειάζεται. </br>
# Επίσης, παρατηρούμε πως το μοντέλο μας έχει φτάσει μια πολύ κάλη τιμή στο recall και την σχεδόν τελική τιμή στο precision από τις 30 ταινίες.
